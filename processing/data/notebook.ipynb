# %%
import pandas as pd
import sqlite3

DB_PATH = "chunks.db"

conn = sqlite3.connect(DB_PATH)
df = pd.read_sql_query("SELECT * FROM chunks", conn)
conn.close()

df
# Out:
#       id                                                url  \
# 0      1               https://www.bancolombia.com/personas
# 1      2  https://www.bancolombia.com/personas/tarjetas-...
# 2      3  https://www.bancolombia.com/personas/tarjetas-...
# 3      4  https://www.bancolombia.com/personas/tarjetas-...
# 4      5  https://www.bancolombia.com/personas/transacci...
# ..   ...                                                ...
# 244  245  https://www.bancolombia.com/personas/productos...
# 245  246  https://www.bancolombia.com/personas/productos...
# 246  247  https://www.bancolombia.com/personas/productos...
# 247  248  https://www.bancolombia.com/personas/productos...
# 248  249  https://www.bancolombia.com/personas/productos...
#
#                                                  title             category  \
# 0                                 Bancolombia Personas              general
# 1    Tarjetas de crédito Bancolombia para que pague...  tarjetas_de_credito
# ...
